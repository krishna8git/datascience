# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
df = pd.read_csv('Bread_Cheese.csv')
df.shape
# Out:
# (5, 4)

# %%
df
# Out:
#     Bread  Cheese    Eggs  Juice
# 0   Bread  Cheese   Juice    NaN
# 1   Bread    Milk  Yogurt    NaN
# 2   Bread   Juice    Milk    NaN
# 3  Cheese   Juice    Milk    NaN
# 4    Milk  Yogurt     NaN    NaN

# %%
trans = [line.rstrip().split(',') for line in open('Bread_Cheese.csv')]
trans
# Out:
# [['Bread', 'Cheese', 'Eggs', 'Juice'],
#  ['Bread', 'Cheese', 'Juice'],
#  ['Bread', 'Milk', 'Yogurt'],
#  ['Bread', 'Juice', 'Milk'],
#  ['Cheese', 'Juice', 'Milk'],
#  ['Milk', 'Yogurt']]

# %%
# just to see
pd.read_csv('Bread_Cheese.csv', header = None, encoding = 'UTF-8' )
# Out:
#         0       1       2      3
# 0   Bread  Cheese    Eggs  Juice
# 1   Bread  Cheese   Juice    NaN
# 2   Bread    Milk  Yogurt    NaN
# 3   Bread   Juice    Milk    NaN
# 4  Cheese   Juice    Milk    NaN
# 5    Milk  Yogurt     NaN    NaN

# %%
te = TransactionEncoder()
te_ary = te.fit(trans).transform(trans)
te_ary
# Out:
# array([[ True,  True,  True,  True, False, False],
#        [ True,  True, False,  True, False, False],
#        [ True, False, False, False,  True,  True],
#        [ True, False, False,  True,  True, False],
#        [False,  True, False,  True,  True, False],
#        [False, False, False, False,  True,  True]])

# %%
int_te_ary = te_ary.astype('int')

# %%
df_trans = pd.DataFrame(int_te_ary)

# %% [markdown]
# ### Columns Mapping after TransactionEncoder

# %%
te.columns_
# Out:
# ['Bread', 'Cheese', 'Eggs', 'Juice', 'Milk', 'Yogurt']

# %%
te.columns_mapping_
# Out:
# {'Bread': 0, 'Cheese': 1, 'Eggs': 2, 'Juice': 3, 'Milk': 4, 'Yogurt': 5}

# %%
df_trans.columns = te.columns_

# %%
df_trans
# Out:
#    Bread  Cheese  Eggs  Juice  Milk  Yogurt
# 0      1       1     1      1     0       0
# 1      1       1     0      1     0       0
# 2      1       0     0      0     1       1
# 3      1       0     0      1     1       0
# 4      0       1     0      1     1       0
# 5      0       0     0      0     1       1

# %% [markdown]
# ### Step1: Generate Frequent Item Sets

# %%
# Generate frequent itemsets
x = time.time()
frequent_itemsets = apriori(df_trans, min_support = 0.16, use_colnames = True)

# use min support to start with
y = time.time()

print("Time in Seconds %s"% (y-x))
# Out:
# Time in Seconds 0.021896839141845703

# %%
frequent_itemsets
# Out:
#      support                      itemsets
# 0   0.666667                       (Bread)
# 1   0.500000                      (Cheese)
# 2   0.166667                        (Eggs)
# 3   0.666667                       (Juice)
# 4   0.666667                        (Milk)
# 5   0.333333                      (Yogurt)
# 6   0.333333               (Cheese, Bread)
# 7   0.166667                 (Eggs, Bread)
# 8   0.500000                (Juice, Bread)
# 9   0.333333                 (Milk, Bread)
# 10  0.166667               (Yogurt, Bread)
# 11  0.166667                (Cheese, Eggs)
# 12  0.500000               (Cheese, Juice)
# 13  0.166667                (Cheese, Milk)
# 14  0.166667                 (Juice, Eggs)
# 15  0.333333                 (Juice, Milk)
# 16  0.333333                (Milk, Yogurt)
# 17  0.166667         (Cheese, Eggs, Bread)
# 18  0.333333        (Cheese, Juice, Bread)
# 19  0.166667          (Juice, Eggs, Bread)
# 20  0.166667          (Juice, Milk, Bread)
# 21  0.166667         (Milk, Yogurt, Bread)
# 22  0.166667         (Cheese, Eggs, Juice)
# 23  0.166667         (Cheese, Juice, Milk)
# 24  0.166667  (Cheese, Eggs, Juice, Bread)

# %% [markdown]
# This gives us the non-empty subsets which are satisfying the minimum support criteria.

# %% [markdown]
# ### Step2: Generate Association Rules

# %%
rules = association_rules(frequent_itemsets)
rules.shape
# Out:
# (24, 9)

# %%
rules
# Out:
#               antecedents             consequents  antecedent support  \
# 0                  (Eggs)                 (Bread)            0.166667
# 1                  (Eggs)                (Cheese)            0.166667
# 2                (Cheese)                 (Juice)            0.500000
# 3                  (Eggs)                 (Juice)            0.166667
# 4                (Yogurt)                  (Milk)            0.333333
# 5          (Cheese, Eggs)                 (Bread)            0.166667
# 6           (Eggs, Bread)                (Cheese)            0.166667
# 7                  (Eggs)         (Cheese, Bread)            0.166667
# 8         (Cheese, Bread)                 (Juice)            0.333333
# 9           (Juice, Eggs)                 (Bread)            0.166667
# 10          (Eggs, Bread)                 (Juice)            0.166667
# 11                 (Eggs)          (Juice, Bread)            0.166667
# 12        (Yogurt, Bread)                  (Milk)            0.166667
# 13         (Cheese, Eggs)                 (Juice)            0.166667
# 14          (Juice, Eggs)                (Cheese)            0.166667
# 15                 (Eggs)         (Cheese, Juice)            0.166667
# 16         (Cheese, Milk)                 (Juice)            0.166667
# 17  (Cheese, Eggs, Juice)                 (Bread)            0.166667
# 18  (Cheese, Eggs, Bread)                 (Juice)            0.166667
# 19   (Juice, Eggs, Bread)                (Cheese)            0.166667
# 20         (Cheese, Eggs)          (Juice, Bread)            0.166667
# 21          (Juice, Eggs)         (Cheese, Bread)            0.166667
# 22          (Eggs, Bread)         (Cheese, Juice)            0.166667
# 23                 (Eggs)  (Cheese, Juice, Bread)            0.166667
#
#     consequent support   support  confidence  lift  leverage  conviction
# 0             0.666667  0.166667         1.0   1.5  0.055556         inf
# 1             0.500000  0.166667         1.0   2.0  0.083333         inf
# 2             0.666667  0.500000         1.0   1.5  0.166667         inf
# 3             0.666667  0.166667         1.0   1.5  0.055556         inf
# 4             0.666667  0.333333         1.0   1.5  0.111111         inf
# 5             0.666667  0.166667         1.0   1.5  0.055556         inf
# 6             0.500000  0.166667         1.0   2.0  0.083333         inf
# 7             0.333333  0.166667         1.0   3.0  0.111111         inf
# 8             0.666667  0.333333         1.0   1.5  0.111111         inf
# 9             0.666667  0.166667         1.0   1.5  0.055556         inf
# 10            0.666667  0.166667         1.0   1.5  0.055556         inf
# 11            0.500000  0.166667         1.0   2.0  0.083333         inf
# 12            0.666667  0.166667         1.0   1.5  0.055556         inf
# 13            0.666667  0.166667         1.0   1.5  0.055556         inf
# 14            0.500000  0.166667         1.0   2.0  0.083333         inf
# 15            0.500000  0.166667         1.0   2.0  0.083333         inf
# 16            0.666667  0.166667         1.0   1.5  0.055556         inf
# 17            0.666667  0.166667         1.0   1.5  0.055556         inf
# 18            0.666667  0.166667         1.0   1.5  0.055556         inf
# 19            0.500000  0.166667         1.0   2.0  0.083333         inf
# 20            0.500000  0.166667         1.0   2.0  0.083333         inf
# 21            0.333333  0.166667         1.0   3.0  0.111111         inf
# 22            0.500000  0.166667         1.0   2.0  0.083333         inf
# 23            0.333333  0.166667         1.0   3.0  0.111111         inf

# %%
rules[(rules['lift'] >= 2)].iloc[:, 0:7]
# Out:
#              antecedents             consequents  antecedent support  \
# 1                 (Eggs)                (Cheese)            0.166667
# 6          (Eggs, Bread)                (Cheese)            0.166667
# 7                 (Eggs)         (Cheese, Bread)            0.166667
# 11                (Eggs)          (Juice, Bread)            0.166667
# 14         (Juice, Eggs)                (Cheese)            0.166667
# 15                (Eggs)         (Cheese, Juice)            0.166667
# 19  (Juice, Eggs, Bread)                (Cheese)            0.166667
# 20        (Cheese, Eggs)          (Juice, Bread)            0.166667
# 21         (Juice, Eggs)         (Cheese, Bread)            0.166667
# 22         (Eggs, Bread)         (Cheese, Juice)            0.166667
# 23                (Eggs)  (Cheese, Juice, Bread)            0.166667
#
#     consequent support   support  confidence  lift
# 1             0.500000  0.166667         1.0   2.0
# 6             0.500000  0.166667         1.0   2.0
# 7             0.333333  0.166667         1.0   3.0
# 11            0.500000  0.166667         1.0   2.0
# 14            0.500000  0.166667         1.0   2.0
# 15            0.500000  0.166667         1.0   2.0
# 19            0.500000  0.166667         1.0   2.0
# 20            0.500000  0.166667         1.0   2.0
# 21            0.333333  0.166667         1.0   3.0
# 22            0.500000  0.166667         1.0   2.0
# 23            0.333333  0.166667         1.0   3.0
