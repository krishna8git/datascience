# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/automobileEDA.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               4
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# city-L/100km         0
# horsepower-binned    1
# diesel               0
# gas                  0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                    count          mean          std          min          25%  \
# symboling          201.0      0.840796     1.254802    -2.000000     0.000000
# normalized-losses  201.0    122.000000    31.996250    65.000000   101.000000
# wheel-base         201.0     98.797015     6.066366    86.600000    94.500000
# length             201.0      0.837102     0.059213     0.678039     0.801538
# width              201.0      0.915126     0.029187     0.837500     0.890278
# height             201.0     53.766667     2.447822    47.800000    52.000000
# curb-weight        201.0   2555.666667   517.296727  1488.000000  2169.000000
# engine-size        201.0    126.875622    41.546834    61.000000    98.000000
# bore               201.0      3.330692     0.268072     2.540000     3.150000
# stroke             197.0      3.256904     0.319256     2.070000     3.110000
# compression-ratio  201.0     10.164279     4.004965     7.000000     8.600000
# ...

# %%
df_mini = pd.DataFrame()
x = np.arange(10, 20)
y = 3 * x + 10
df_mini['X'] = x
df_mini['Y'] = y
df_mini
# Out:
#     X   Y
# 0  10  40
# 1  11  43
# 2  12  46
# 3  13  49
# 4  14  52
# 5  15  55
# 6  16  58
# 7  17  61
# 8  18  64
# 9  19  67

# %%
sns.regplot(x, y, color='red')

# %%
from sklearn.linear_model import LinearRegression

lm = LinearRegression()
model = lm.fit(df_mini[['X']], df_mini.Y)

# %%
model.coef_
# Out:
# array([3.])

# %%
model.intercept_
# Out:
# 10.000000000000021

# %%
model.predict([[2]])
# Out:
# array([16.])

# %%
model.predict([[3]])
# Out:
# array([19.])

# %%
model.predict(df_mini[['X']])
# Out:
# array([40., 43., 46., 49., 52., 55., 58., 61., 64., 67.])

# %%
df_mini
# Out:
#     X   Y
# 0  10  40
# 1  11  43
# 2  12  46
# 3  13  49
# 4  14  52
# 5  15  55
# 6  16  58
# 7  17  61
# 8  18  64
# 9  19  67

# %%
sns.residplot(x, y)

# %%
df.head().transpose()
# Out:
#                              0            1            2         3         4
# symboling                    3            3            1         2         2
# normalized-losses          122          122          122       164       164
# make               alfa-romero  alfa-romero  alfa-romero      audi      audi
# aspiration                 std          std          std       std       std
# num-of-doors               two          two          two      four      four
# body-style         convertible  convertible    hatchback     sedan     sedan
# drive-wheels               rwd          rwd          rwd       fwd       4wd
# engine-location          front        front        front     front     front
# wheel-base                88.6         88.6         94.5      99.8      99.4
# length                0.811148     0.811148     0.822681   0.84863   0.84863
# width                 0.890278     0.890278     0.909722  0.919444  0.922222
# ...

# %%
sns.regplot(df['highway-mpg'], df['price'])

# %%
sns.residplot(df['highway-mpg'], df['price'])

# %%
lm_car_price = LinearRegression()
model_carprice = lm_car_price.fit(df[['highway-mpg']], df.price)

# %%
model_carprice.coef_
# Out:
# array([-821.73337832])

# %%
model_carprice.intercept_
# Out:
# 38423.305858157386

# %%
Yhat = model_carprice.predict(df[['highway-mpg']])

# %%
Yactual = df.price

# %%
plt.figure(figsize = (10, 6))
sns.distplot(Yactual, hist = False, color = 'RED', label='Actual Values')
sns.distplot(Yhat, hist = False, color = 'BLUE', label = "Predicted Values")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# path of data 
path = 'https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/automobileEDA.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
df.to_csv('model_development.csv')
